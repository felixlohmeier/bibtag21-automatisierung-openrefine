# %% [markdown]
# # Schritt 3: Ergebnisse im Browser prüfen
#
# Prüfen Sie abschließend in der Benutzeroberfläche von OpenRefine das Ergebnis.
#
# Führen Sie den folgenden Befehl aus, um den Link zur OpenRefine Benutzeroberfläche zu erhalten.

# %%
# %%javascript
# element.innerHTML = '<h3><a href='
#     + window.location.href.replace(/lab.*/,'proxy/3333/')
#     + ' target="_blank" style="color:#1976D2; text-decoration: underline">'
#     + 'Hier klicken um die Benutzeroberfläche von OpenRefine zu öffnen'
#     + '</a></h3>'
