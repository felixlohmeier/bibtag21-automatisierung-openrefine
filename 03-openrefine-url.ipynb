# %% [markdown]
# # Schritt 3: Ergebnisse im Browser prüfen
#
# Prüfen Sie abschließend in der Benutzeroberfläche von OpenRefine das Ergebnis.
#
# Führen Sie den folgenden Befehl aus, um den Link zur OpenRefine Benutzeroberfläche zu erhalten.

# %%
import os
notebook = !jupyter notebook list | grep -o -E 'user\S+'
openrefine_url = notebook[0].replace('?token', 'proxy/3333/?token')
from IPython.core.display import display, HTML
display(HTML('<a href="' + openrefine_url + '" target="blank">Click here to open OpenRefine</a>'))
