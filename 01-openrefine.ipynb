# %% [markdown]
# # Schritt 1: OpenRefine Server starten
#
# Starten Sie hier als erstes den OpenRefine-Server, in dem Sie den vorbereiteten Befehl mit dem Play-Button "abspielen".

# %%
openrefine/refine -d data
